# %%
import os

import numpy as np
import tensorflow as tf
from tensorflow import keras
import cv2

import matplotlib.pyplot as plt
import ipympl

from typing import Tuple

# %% [markdown]
# # Standard CV2 circle detection (Hough Circle)

# %%
img = cv2.cvtColor(cv2.imread(os.path.join("raw", "image.png")), cv2.COLOR_BGR2GRAY)
output = img.copy()

circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT, 1, 20, param1=50, param2=30, minRadius=40, maxRadius=60)

if circles is not None:
    circles = np.round(circles[0, :]).astype("int")
    for (x, y, r) in circles:
        cv2.circle(output, (x, y), r, (0, 255, 0), 4)
        cv2.rectangle(output, (x-5, y-5), (x+5, y+5), (0, 128, 255), -1)
    
fig, ax = plt.subplots(ncols=2, sharex=True, sharey=True)
ax[0].imshow(img, cmap='gray')
ax[1].imshow(output, cmap='gray')

# %% [markdown]
# # Helper functions for plotting

# %%
def to_three_channels(_label: np.ndarray) -> np.ndarray:
    return np.squeeze(np.stack((_label, _label, _label), 2))

def show_sample(_image: np.ndarray, _label: np.ndarray):
    fig, ax = plt.subplots(ncols=2, sharex=True, sharey=True)
    ax[0].imshow(_image, cmap="gray")
    ax[1].imshow(to_three_channels(_label), cmap="gray")
    fig.tight_layout()
    
def show_batch(_images: np.ndarray, _labels: np.ndarray):
    show_sample(_images[0, :, :, :], _labels[0, :, :, :])
    
def show_result(_images: np.ndarray, _labels: np.ndarray, _preds: np.ndarray):
    fig, ax = plt.subplots(ncols=3, sharex=True, sharey=True, figsize=(15, 7))
    ax[0].imshow(_images[0, :, :, :], cmap="gray")
    ax[0].set_title("Raw")
    ax[1].imshow(to_three_channels(_labels[0, :, :, :]), cmap="gray")
    ax[1].set_title("Labelled")
    ax[2].imshow(to_three_channels(_preds[0, :, :, :]), cmap="gray")
    ax[2].set_title("Neural Network")
    fig.tight_layout()

# %% [markdown]
# # Test data

# %%
def add_square(_img: np.ndarray, center: tuple, width: int):
    start_point = (center[0] - width, center[1] - width)
    end_point   = (center[0] + width, center[1] + width)
    cv2.rectangle(_img, start_point, end_point, random_color(), cv2.FILLED)

def random_color():
    return np.random.rand(3)

def create_data_sample(num_shapes: int, height: int, width: int) -> Tuple[np.ndarray, np.ndarray]:
    _img = np.zeros((height, width, 3))
    _label = np.zeros((height, width, 1))
    for _ in range(num_shapes):
        x = int(np.random.rand() * width)
        y = int(np.random.rand() * height)
        if np.random.rand() > 0.5:
            cv2.circle(_img, (x,y), int(np.ceil(width * 0.05)), random_color(), cv2.FILLED)
            cv2.circle(_label, (x,y), int(np.ceil(width * 0.02)), (1, 1, 1), cv2.FILLED)
        else: 
            add_square(_img, (x,y), int(np.ceil(width * 0.05 * 0.7)))
    return _img, _label

def test_batch(num_shapes: int, height: int, width: int) -> np.ndarray:
    _img, _label = create_data_sample(num_shapes, height, width)
    return np.expand_dims(_img, 0), np.expand_dims(_label, 0)

# %% [markdown]
# ### Sample test data

# %%
# %matplotlib widget
img_shape = (128, 128, 3)
img, label = create_data_sample(10, img_shape[0], img_shape[1])

show_sample(img, label)
print(img.shape, label.shape)

# %% [markdown]
# ### Batch test data

# %%
img_batch = []
label_batch = []

for idx in range(1000):
    img, label  = create_data_sample(10, img_shape[0], img_shape[1])
    img_batch.append(img)
    label_batch.append(label)
    
img_batch = np.array(img_batch)
label_batch = np.array(label_batch)

print(img_batch.shape, label_batch.shape)
show_batch(img_batch, label_batch)

# %% [markdown]
# # Real data

# %%
def load_image(image_path: str, circle_label: tuple, overlay: bool = False) -> Tuple[np.ndarray, np.ndarray]:
    raw = cv2.bitwise_not(cv2.imread(image_path))
    _, image = cv2.threshold(raw, 80, 255, cv2.THRESH_BINARY)
    image = image.astype("float32") / 255
    
    label = np.zeros((image.shape[0], image.shape[1], 1), dtype="float32")
    cv2.circle(label, (circle_label[0], circle_label[1]), int(np.ceil(label.shape[1] * circle_label[2])), (1, 1, 1))
    if overlay:
        cv2.circle(image, (circle_label[0], circle_label[1]), int(np.ceil(label.shape[1] * circle[2])), (1, 1, 1))
        
    return image, label

def load_images_from_folder(folder: str, circle_labels: list) -> Tuple[np.ndarray, np.ndarray]:
    image_files = os.listdir(folder)
    num_images = len(image_files)
    num_labels = len(circle_labels)
    
    if num_images != num_labels:
        raise ValueError(f"Invalid number of labels ({num_labels}) for images ({num_images})")
        
    images = []
    labels = []
    for idx, image in enumerate(image_files):
        image, label = load_image(os.path.join(folder, image), circle_labels[idx])
        images.append(image)
        labels.append(label)
        
    images = np.array(images)
    labels = np.array(labels)

    return images, labels

def load_test_image(image_path: str, circle_label: tuple) -> Tuple[np.ndarray, np.ndarray]:
    image, label = load_image(image_path, circle_label)
    return np.expand_dims(image, 0), np.expand_dims(label, 0)

# %% [markdown]
# ### Sample real data

# %%
img, label = load_image(os.path.join("training_data", "image.png"), (295, 175, 0.08), overlay=False)

img_shape = img.shape

print(img.shape, label.shape)
show_sample(img, label)
# Out:
# (478, 632, 3) (478, 632, 1)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Batch real data

# %%
img_batch, label_batch = load_images_from_folder("training_data", [(295, 175, 0.08)])

print(img_batch.shape, label_batch.shape)
show_batch(img_batch, label_batch)
# Out:
# (1, 478, 632, 3) (1, 478, 632, 1)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Convolutional Neural Network (CNN)

# %% [markdown]
# ## 3 layer network

# %%
inputs = keras.Input(shape=img.shape)
conv1 = keras.layers.Conv2D(16, 5, padding='same', activation='relu', kernel_initializer='glorot_normal', kernel_regularizer=None)(inputs)
conv1 = keras.layers.BatchNormalization(momentum=0.99)(conv1)
conv2 = keras.layers.Conv2D(32,5, padding='same', activation='relu', kernel_initializer='glorot_normal', kernel_regularizer=None)(conv1)
conv2 = keras.layers.BatchNormalization(momentum=0.99)(conv2)
outputs = keras.layers.Conv2D(1,5, padding='same', activation='relu', kernel_initializer='glorot_normal', kernel_regularizer=None)(conv2)
model = keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 478, 632, 3)]     0
#
#  conv2d (Conv2D)             (None, 478, 632, 16)      1216
#
#  batch_normalization (BatchN  (None, 478, 632, 16)     64
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 478, 632, 32)      12832
#
#  batch_normalization_1 (Batc  (None, 478, 632, 32)     128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 478, 632, 1)       801
#
# =================================================================
# Total params: 15,041
# Trainable params: 14,945
# Non-trainable params: 96
# _________________________________________________________________

# %% [markdown]
# ## Define a reduced mean square loss function

# %%
def loss_function(y_true, y_pred):
    squared_diff = tf.square(y_true - y_pred)
    return tf.reduce_mean(squared_diff)

# %% [markdown]
# ## Compile CNN optimizer

# %%
opt = keras.optimizers.Adam(learning_rate=5e-4)
model.compile(optimizer=opt,loss=loss_function)

# %%
model.fit(img_batch, label_batch, batch_size=100, epochs=100)
# Out:
# 2022-04-25 13:09:52.241828: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0
# 1/1 [==============================] - 0s 431ms/step - loss: 0.0093
# Epoch 49/100
# 1/1 [==============================] - 0s 461ms/step - loss: 0.0088
# Epoch 50/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0083
# Epoch 51/100
# 1/1 [==============================] - 1s 877ms/step - loss: 0.0077
# Epoch 52/100
# 1/1 [==============================] - 1s 917ms/step - loss: 0.0077
# Epoch 53/100
# 1/1 [==============================] - 1s 544ms/step - loss: 0.0074
# Epoch 54/100
# 1/1 [==============================] - 0s 454ms/step - loss: 0.0071
# Epoch 55/100
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0069
# Epoch 56/100
# 1/1 [==============================] - 0s 455ms/step - loss: 0.0070
# Epoch 57/100
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0067
# Epoch 58/100
# 1/1 [==============================] - 1s 915ms/step - loss: 0.0063
# Epoch 59/100
# 1/1 [==============================] - 1s 622ms/step - loss: 0.0062
# Epoch 60/100
# 1/1 [==============================] - 1s 981ms/step - loss: 0.0061
# Epoch 61/100
# 1/1 [==============================] - 0s 453ms/step - loss: 0.0058
# Epoch 62/100
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0055
# Epoch 63/100
# 1/1 [==============================] - 0s 465ms/step - loss: 0.0052
# Epoch 64/100
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0051
# Epoch 65/100
# 1/1 [==============================] - 0s 426ms/step - loss: 0.0052
# Epoch 66/100
# 1/1 [==============================] - 0s 420ms/step - loss: 0.0052
# Epoch 67/100
# 1/1 [==============================] - 0s 491ms/step - loss: 0.0050
# Epoch 68/100
# 1/1 [==============================] - 1s 531ms/step - loss: 0.0047
# Epoch 69/100
# 1/1 [==============================] - 0s 467ms/step - loss: 0.0046
# Epoch 70/100
# 1/1 [==============================] - 1s 758ms/step - loss: 0.0045
# Epoch 71/100
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0043
# Epoch 72/100
# 1/1 [==============================] - 0s 420ms/step - loss: 0.0043
# Epoch 73/100
# 1/1 [==============================] - 0s 421ms/step - loss: 0.0042
# Epoch 74/100
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0041
# Epoch 75/100
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0040
# Epoch 76/100
# 1/1 [==============================] - 0s 443ms/step - loss: 0.0040
# Epoch 77/100
# 1/1 [==============================] - 0s 473ms/step - loss: 0.0038
# Epoch 78/100
# 1/1 [==============================] - 1s 730ms/step - loss: 0.0037
# Epoch 79/100
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0036
# Epoch 80/100
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0036
# Epoch 81/100
# 1/1 [==============================] - 0s 431ms/step - loss: 0.0037
# Epoch 82/100
# 1/1 [==============================] - 0s 420ms/step - loss: 0.0036
# Epoch 83/100
# 1/1 [==============================] - 0s 421ms/step - loss: 0.0035
# Epoch 84/100
# 1/1 [==============================] - 0s 425ms/step - loss: 0.0034
# Epoch 85/100
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0034
# Epoch 86/100
# 1/1 [==============================] - 1s 590ms/step - loss: 0.0033
# Epoch 87/100
# 1/1 [==============================] - 1s 818ms/step - loss: 0.0032
# Epoch 88/100
# 1/1 [==============================] - 1s 881ms/step - loss: 0.0031
# Epoch 89/100
# 1/1 [==============================] - 0s 449ms/step - loss: 0.0031
# Epoch 90/100
# 1/1 [==============================] - 1s 884ms/step - loss: 0.0030
# Epoch 91/100
# 1/1 [==============================] - 0s 462ms/step - loss: 0.0030
# Epoch 92/100
# 1/1 [==============================] - 0s 475ms/step - loss: 0.0029
# Epoch 93/100
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0029
# Epoch 94/100
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0029
# Epoch 95/100
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0028
# Epoch 96/100
# 1/1 [==============================] - 0s 456ms/step - loss: 0.0028
# Epoch 97/100
# 1/1 [==============================] - 0s 439ms/step - loss: 0.0028
# Epoch 98/100
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0027
# Epoch 99/100
# 1/1 [==============================] - 0s 431ms/step - loss: 0.0027
# Epoch 100/100
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0026

# %% [markdown]
# # Visualize results

# %% [markdown]
# ### Test data results

# %%
img, label = test_batch(10, img_shape[0], img_shape[1])
pred = model.predict(img)

show_result(img, label, pred)

# %% [markdown]
# ### Real data results

# %%
img, label = load_test_image(os.path.join("testing_data", "image.png"), (295, 175, 0.08))
pred = model.predict(img)

show_result(img, label, pred)
